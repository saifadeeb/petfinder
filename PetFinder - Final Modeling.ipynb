# %%
#libraries
import sys
import collections
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import mode
from scipy.spatial.distance import squareform
import seaborn as sns
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.preprocessing import Imputer
from sklearn import preprocessing
from sklearn import utils
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import scale
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import time

plt.style.use('bmh')
# %matplotlib inline

# %%
#import the train dataset
pet = pd.read_csv('data/all_train_features.csv', sep = ',')
pet.describe()
# Out:
#                Type           Age        Age_Yr        Breed1        Breed2  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       1.457547     10.452078      0.651637    265.287267     74.009738
# std        0.498211     18.155790      1.558780     60.024977    123.011575
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      2.000000      0.000000    265.000000      0.000000
# 50%        1.000000      3.000000      0.000000    266.000000      0.000000
# 75%        2.000000     12.000000      1.000000    307.000000    179.000000
# max        2.000000    255.000000     21.000000    307.000000    307.000000
#
#              Gender        Color1        Color2        Color3  MaturitySize  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       1.776162      2.234176      3.222837      1.882012      1.862002
# std        0.681592      1.745225      2.742562      2.984086      0.547959
# min        1.000000      1.000000      0.000000      0.000000      1.000000
# 25%        1.000000      1.000000      0.000000      0.000000      2.000000
# 50%        2.000000      2.000000      2.000000      0.000000      2.000000
# 75%        2.000000      3.000000      6.000000      5.000000      2.000000
# max        3.000000      7.000000      7.000000      7.000000      4.000000
#
#        ...  2017GDPpercapita_USD  2017GDPpercapita_RM  segmentation_cluster  \
# count  ...          14993.000000         14993.000000          14993.000000
# mean   ...          15818.693991         62912.072634              4.029547
# std    ...           7254.001448         28848.942564              1.444267
# min    ...           3417.000000         13593.000000              1.000000
# 25%    ...          12092.000000         48091.000000              3.000000
# 50%    ...          12092.000000         48091.000000              4.000000
# 75%    ...          27991.000000        111321.000000              5.000000
# max    ...          27991.000000        111321.000000              7.000000
#
#            dullness     whiteness     image_size         width        height  \
# count  14580.000000  14580.000000   14580.000000  14580.000000  14580.000000
# mean       7.902833      5.274038   28175.772908    394.469547    397.555144
# std       12.875601     11.434940   16305.008637    125.604215     95.429491
# min       -1.000000     -1.000000    1672.000000     60.000000     67.000000
# 25%        0.020000      0.000000   17516.500000    300.000000    300.000000
# 50%        1.867500      0.100000   23600.000000    399.000000    400.000000
# 75%       10.360000      4.487500   33691.000000    400.000000    480.000000
# max       92.005000     98.450000  181209.000000    640.000000    640.000000
#
#           blurrness  colorfulness
# count  14580.000000  14580.000000
# mean    1100.173627    139.129558
# std     1560.660009     34.238514
# min        5.599420     22.029729
# 25%      258.070537    117.890751
# 50%      565.967544    148.341768
# 75%     1265.527673    166.425560
# max    27061.401270    193.237653
#
# [8 rows x 36 columns]

# %%
#import test data
pet_test = pd.read_csv('data/all_test_features.csv', sep = ',')
pet_test.describe()
# Out:
#               Type          Age       Age_Yr       Breed1       Breed2  \
# count  3948.000000  3948.000000  3948.000000  3948.000000  3948.000000
# mean      1.526089    11.564590     0.895137   263.033435    57.359422
# std       0.499382    18.568429     1.614680    59.178121   112.086810
# min       1.000000     0.000000     0.000000     2.000000     0.000000
# 25%       1.000000     2.000000     0.000000   265.000000     0.000000
# 50%       2.000000     4.000000     0.000000   266.000000     0.000000
# 75%       2.000000    12.000000     1.000000   307.000000     0.000000
# max       2.000000   180.000000    15.000000   307.000000   307.000000
#
#             Gender       Color1       Color2       Color3  MaturitySize  ...  \
# count  3948.000000  3948.000000  3948.000000  3948.000000   3948.000000  ...
# mean      1.782675     2.232016     3.355623     2.061297      1.824468  ...
# std       0.692633     1.736614     2.700144     3.041357      0.569772  ...
# min       1.000000     1.000000     0.000000     0.000000      1.000000  ...
# 25%       1.000000     1.000000     0.000000     0.000000      1.000000  ...
# 50%       2.000000     2.000000     3.000000     0.000000      2.000000  ...
# 75%       2.000000     3.000000     6.000000     6.000000      2.000000  ...
# max       3.000000     7.000000     7.000000     7.000000      4.000000  ...
#
#        2017GDPpercapita_USD  2017GDPpercapita_RM  segmentation_cluster  \
# count           3948.000000          3948.000000           3815.000000
# mean           16898.866768          2840.417327              3.907471
# std             7780.150152          3082.865689              1.447593
# min             3417.000000            21.181197              1.000000
# 25%            12092.000000           724.839585              3.000000
# 50%            12092.000000           724.839585              4.000000
# 75%            27991.000000          7275.720165              5.000000
# max            27991.000000          7275.720165              7.000000
#
#           dullness    whiteness     image_size        width       height  \
# count  3801.000000  3801.000000    3801.000000  3801.000000  3801.000000
# mean      7.770397     4.909522   28009.816364   393.008419   392.203104
# std      13.009862    11.252791   16550.911797   125.681186    94.891524
# min      -1.000000    -1.000000    1777.000000    80.000000    60.000000
# 25%       0.010000     0.000000   17032.000000   300.000000   300.000000
# 50%       1.700000     0.060000   22961.000000   399.000000   400.000000
# 75%       9.685000     3.725000   34014.000000   400.000000   480.000000
# max      94.660000    87.440000  140151.000000   640.000000   640.000000
#
#           blurrness  colorfulness
# count   3801.000000   3801.000000
# mean    1173.568850    139.554417
# std     1793.580292     35.204636
# min        8.544691     27.597544
# 25%      261.254777    118.630440
# 50%      596.230838    149.707253
# 75%     1387.481044    167.919096
# max    32369.238760    188.823915
#
# [8 rows x 34 columns]

# %%
## TRAINING DATA
#check for missing
#% of columns that are NA
columns = pet.columns
percent_missing = pet.isnull().sum() * 100 / len(pet)
missing_value_df = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True)
missing_value_df

#name is missing - remove column from final training set
# Out:
#                                column_name  percent_missing
# Type                                  Type         0.000000
# Health_Name                    Health_Name         0.000000
# Quantity                          Quantity         0.000000
# State                                State         0.000000
# State_Label                    State_Label         0.000000
# RescuerID                        RescuerID         0.000000
# VideoAmt                          VideoAmt         0.000000
# PetID                                PetID         0.000000
# PhotoAmt                          PhotoAmt         0.000000
# AdoptionSpeed                AdoptionSpeed         0.000000
# FastAdoption                  FastAdoption         0.000000
# StateorTerritory          StateorTerritory         0.000000
# Population                      Population         0.000000
# TotalArea(km2)              TotalArea(km2)         0.000000
# Region                              Region         0.000000
# HDI                                    HDI         0.000000
# Population_Density      Population_Density         0.000000
# 2017GDPpercapita_USD  2017GDPpercapita_USD         0.000000
# 2017GDPpercapita_RM    2017GDPpercapita_RM         0.000000
# segmentation_cluster  segmentation_cluster         0.000000
# has_name                          has_name         0.000000
# has_many_colors            has_many_colors         0.000000
# has_description            has_description         0.000000
# has_fee                            has_fee         0.000000
# Health                              Health         0.000000
# Sterilized_Name            Sterilized_Name         0.000000
# Fee                                    Fee         0.000000
# Dewormed_Name                Dewormed_Name         0.000000
# Type_Name                        Type_Name         0.000000
# Age                                    Age         0.000000
# ...                                    ...              ...
# Breed1                              Breed1         0.000000
# Breed1_Name                    Breed1_Name         0.000000
# Breed2                              Breed2         0.000000
# Breed2_Name                    Breed2_Name         0.000000
# Gender                              Gender         0.000000
# Sterilized                      Sterilized         0.000000
# Color1                              Color1         0.000000
# Color1_Name                    Color1_Name         0.000000
# Color2                              Color2         0.000000
# Gender_Name                    Gender_Name         0.000000
# Color3                              Color3         0.000000
# Color3_Name                    Color3_Name         0.000000
# MaturitySize                  MaturitySize         0.000000
# MaturitySize_Name        MaturitySize_Name         0.000000
# FurLength                        FurLength         0.000000
# FurLength_Name              FurLength_Name         0.000000
# Vaccinated                      Vaccinated         0.000000
# Color2_Name                    Color2_Name         0.000000
# Vaccinated_Name            Vaccinated_Name         0.000000
# Dewormed                          Dewormed         0.000000
# Description                    Description         0.080037
# NLP_cluster                    NLP_cluster         0.847062
# height                              height         2.754619
# width                                width         2.754619
# image_size                      image_size         2.754619
# blurrness                        blurrness         2.754619
# dullness                          dullness         2.754619
# whiteness                        whiteness         2.754619
# colorfulness                  colorfulness         2.754619
# Name                                  Name         8.383912
#
# [61 rows x 2 columns]

# %%
## TESTING DATA
#check for missing
#% of columns that are NA
columns = pet_test.columns
percent_missing = pet_test.isnull().sum() * 100 / len(pet)
missing_value_df = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True)
missing_value_df

#name is missing - remove column from final test set
# Out:
#                                column_name  percent_missing
# Type                                  Type         0.000000
# Health                              Health         0.000000
# Health_Name                    Health_Name         0.000000
# Fee                                    Fee         0.000000
# State                                State         0.000000
# State_Label                    State_Label         0.000000
# RescuerID                        RescuerID         0.000000
# VideoAmt                          VideoAmt         0.000000
# PetID                                PetID         0.000000
# PhotoAmt                          PhotoAmt         0.000000
# StateorTerritory          StateorTerritory         0.000000
# Sterilized_Name            Sterilized_Name         0.000000
# Population                      Population         0.000000
# Region                              Region         0.000000
# HDI                                    HDI         0.000000
# Population_Density      Population_Density         0.000000
# 2017GDPpercapita_USD  2017GDPpercapita_USD         0.000000
# 2017GDPpercapita_RM    2017GDPpercapita_RM         0.000000
# NLP_cluster                    NLP_cluster         0.000000
# has_name                          has_name         0.000000
# has_many_colors            has_many_colors         0.000000
# has_description            has_description         0.000000
# has_fee                            has_fee         0.000000
# TotalArea(km2)              TotalArea(km2)         0.000000
# Sterilized                      Sterilized         0.000000
# Quantity                          Quantity         0.000000
# Dewormed                          Dewormed         0.000000
# Type_Name                        Type_Name         0.000000
# Age                                    Age         0.000000
# Age_Yr                              Age_Yr         0.000000
# Breed1                              Breed1         0.000000
# Breed1_Name                    Breed1_Name         0.000000
# Breed2                              Breed2         0.000000
# Breed2_Name                    Breed2_Name         0.000000
# Dewormed_Name                Dewormed_Name         0.000000
# Gender_Name                    Gender_Name         0.000000
# Color1                              Color1         0.000000
# Color1_Name                    Color1_Name         0.000000
# Gender                              Gender         0.000000
# Color2_Name                    Color2_Name         0.000000
# Color3                              Color3         0.000000
# Color3_Name                    Color3_Name         0.000000
# MaturitySize                  MaturitySize         0.000000
# MaturitySize_Name        MaturitySize_Name         0.000000
# FurLength                        FurLength         0.000000
# FurLength_Name              FurLength_Name         0.000000
# Color2                              Color2         0.000000
# Vaccinated                      Vaccinated         0.000000
# Vaccinated_Name            Vaccinated_Name         0.000000
# Description                    Description         0.013340
# segmentation_cluster  segmentation_cluster         0.887081
# height                              height         0.980458
# width                                width         0.980458
# image_size                      image_size         0.980458
# blurrness                        blurrness         0.980458
# dullness                          dullness         0.980458
# whiteness                        whiteness         0.980458
# colorfulness                  colorfulness         0.980458
# Name                                  Name         2.020943

# %%
X_features = ['Type', 'has_name', 'Age', 'Breed1_Name', 'Breed2_Name', 'Gender_Name',
              'Color1_Name', 'Color2_Name', 'Color3_Name', 'has_many_colors', 'has_description','MaturitySize_Name',
              'FurLength_Name', 'Vaccinated_Name',  'Dewormed_Name', 'Sterilized_Name', 'Health_Name', 'Quantity',
              'Fee', 'has_fee', 'State_Label', 'VideoAmt', 'PhotoAmt', 'StateorTerritory', 'Population',
              'TotalArea(km2)', 'Region', 'HDI', 'Population_Density','2017GDPpercapita_USD', '2017GDPpercapita_RM',
              'segmentation_cluster', 'dullness', 'whiteness','image_size', 'width', 'height',
              'blurrness', 'colorfulness', 'FastAdoption']
modeling_features = pd.get_dummies(pet[X_features])
all_features = modeling_features.columns.tolist()

# %%
test_X_features = ['Type', 'has_name', 'Age', 'Breed1_Name', 'Breed2_Name', 'Gender_Name',
              'Color1_Name', 'Color2_Name', 'Color3_Name', 'has_many_colors', 'has_description','MaturitySize_Name',
              'FurLength_Name', 'Vaccinated_Name',  'Dewormed_Name', 'Sterilized_Name', 'Health_Name', 'Quantity',
              'Fee', 'has_fee', 'State_Label', 'VideoAmt', 'PhotoAmt', 'StateorTerritory', 'Population',
              'TotalArea(km2)', 'Region', 'HDI', 'Population_Density','2017GDPpercapita_USD', '2017GDPpercapita_RM',
              'segmentation_cluster', 'dullness', 'whiteness','image_size', 'width', 'height',
              'blurrness', 'colorfulness']
test_modeling_features = pd.get_dummies(pet_test[test_X_features])
test_all_features = test_modeling_features.columns.tolist()

# %%
###################### Modeling ######################

#dataprep for TRAINING DATA

#split into X & Y

X = modeling_features[all_features].drop('FastAdoption', axis = 1)
X.replace(' ', '')
Y = modeling_features['FastAdoption']
Y = Y.astype('int')
Y = Y.values.ravel()

#split data into test and train
validation_size = .2
random_seed = 1234

X.fillna(0, inplace=True)

# %%
###################### Modeling ######################

#dataprep for TESTING DATA

#split into X & Y

final_test_X = test_modeling_features[test_all_features]
final_test_X.replace(' ', '')
#Y = modeling_features['FastAdoption']
#Y = Y.astype('int')
#Y = Y.values.ravel()

final_test_X.fillna(0, inplace=True)

# %%
#adding columns from testing data to training data
for i in final_test_X.columns:
    if i not in X.columns:
        print("Adding Variable to Train Set: ", i)
        X[i] = 0
# Out:
# Adding Variable to Train Set:  Breed1_Name_Afghan Hound
# Adding Variable to Train Set:  Breed1_Name_Alaskan Malamute
# Adding Variable to Train Set:  Breed1_Name_Australian Cattle Dog/Blue Heeler
# Adding Variable to Train Set:  Breed1_Name_Cairn Terrier
# Adding Variable to Train Set:  Breed1_Name_Chinchilla
# Adding Variable to Train Set:  Breed1_Name_Fila Brasileiro
# Adding Variable to Train Set:  Breed1_Name_German Shorthaired Pointer
# Adding Variable to Train Set:  Breed1_Name_Great Pyrenees
# Adding Variable to Train Set:  Breed1_Name_Havanese
# Adding Variable to Train Set:  Breed1_Name_Italian Greyhound
# Adding Variable to Train Set:  Breed1_Name_Lakeland Terrier
# Adding Variable to Train Set:  Breed1_Name_Munchkin
# Adding Variable to Train Set:  Breed1_Name_Tibetan Terrier
# Adding Variable to Train Set:  Breed2_Name_Burmilla
# Adding Variable to Train Set:  Breed2_Name_Cairn Terrier
# Adding Variable to Train Set:  Breed2_Name_Chinchilla
# Adding Variable to Train Set:  Breed2_Name_Chinese Foo Dog
# Adding Variable to Train Set:  Breed2_Name_Devon Rex
# Adding Variable to Train Set:  Breed2_Name_Eskimo Dog
# Adding Variable to Train Set:  Breed2_Name_French Bulldog
# Adding Variable to Train Set:  Breed2_Name_Norwegian Forest Cat
# Adding Variable to Train Set:  Breed2_Name_Ocicat
# Adding Variable to Train Set:  Breed2_Name_Old English Sheepdog
# Adding Variable to Train Set:  Breed2_Name_Patterdale Terrier (Fell Terrier)
# Adding Variable to Train Set:  Breed2_Name_Somali
# Adding Variable to Train Set:  Breed2_Name_Whippet

# %%
#adding columns from training data to testing data
for i in X.columns:
    if i not in final_test_X.columns:
        print("Adding Variable to Test Set: ", i)
        final_test_X[i] = 0
# Out:
# Adding Variable to Test Set:  Breed1_Name_0
# Adding Variable to Test Set:  Breed1_Name_Affenpinscher
# Adding Variable to Test Set:  Breed1_Name_Airedale Terrier
# Adding Variable to Test Set:  Breed1_Name_American Water Spaniel
# Adding Variable to Test Set:  Breed1_Name_American Wirehair
# Adding Variable to Test Set:  Breed1_Name_Australian Kelpie
# Adding Variable to Test Set:  Breed1_Name_Australian Shepherd
# Adding Variable to Test Set:  Breed1_Name_Bedlington Terrier
# Adding Variable to Test Set:  Breed1_Name_Black Mouth Cur
# Adding Variable to Test Set:  Breed1_Name_Boston Terrier
# Adding Variable to Test Set:  Breed1_Name_Chartreux
# Adding Variable to Test Set:  Breed1_Name_Chausie
# Adding Variable to Test Set:  Breed1_Name_Chinese Crested Dog
# Adding Variable to Test Set:  Breed1_Name_Chocolate Labrador Retriever
# Adding Variable to Test Set:  Breed1_Name_Coonhound
# Adding Variable to Test Set:  Breed1_Name_Dutch Shepherd
# Adding Variable to Test Set:  Breed1_Name_English Pointer
# Adding Variable to Test Set:  Breed1_Name_English Springer Spaniel
# Adding Variable to Test Set:  Breed1_Name_Extra-Toes Cat (Hemingway Polydactyl)
# Adding Variable to Test Set:  Breed1_Name_Field Spaniel
# Adding Variable to Test Set:  Breed1_Name_Flat-coated Retriever
# Adding Variable to Test Set:  Breed1_Name_Fox Terrier
# Adding Variable to Test Set:  Breed1_Name_Foxhound
# Adding Variable to Test Set:  Breed1_Name_French Bulldog
# Adding Variable to Test Set:  Breed1_Name_Glen of Imaal Terrier
# Adding Variable to Test Set:  Breed1_Name_Great Dane
# Adding Variable to Test Set:  Breed1_Name_Greyhound
# Adding Variable to Test Set:  Breed1_Name_Havana
# Adding Variable to Test Set:  Breed1_Name_Irish Terrier
# Adding Variable to Test Set:  Breed1_Name_Irish Wolfhound
# Adding Variable to Test Set:  Breed1_Name_Jack Russell Terrier (Parson Russell Terrier)
# Adding Variable to Test Set:  Breed1_Name_Japanese Chin
# Adding Variable to Test Set:  Breed1_Name_Javanese
# Adding Variable to Test Set:  Breed1_Name_Kai Dog
# Adding Variable to Test Set:  Breed1_Name_Korat
# Adding Variable to Test Set:  Breed1_Name_Kuvasz
# Adding Variable to Test Set:  Breed1_Name_Lancashire Heeler
# Adding Variable to Test Set:  Breed1_Name_Lhasa Apso
# Adding Variable to Test Set:  Breed1_Name_Lowchen
# Adding Variable to Test Set:  Breed1_Name_Manchester Terrier
# Adding Variable to Test Set:  Breed1_Name_Manx
# Adding Variable to Test Set:  Breed1_Name_Mastiff
# Adding Variable to Test Set:  Breed1_Name_Munsterlander
# Adding Variable to Test Set:  Breed1_Name_Nebelung
# Adding Variable to Test Set:  Breed1_Name_Old English Sheepdog
# Adding Variable to Test Set:  Breed1_Name_Papillon
# Adding Variable to Test Set:  Breed1_Name_Rat Terrier
# Adding Variable to Test Set:  Breed1_Name_Samoyed
# Adding Variable to Test Set:  Breed1_Name_Scottish Fold
# Adding Variable to Test Set:  Breed1_Name_Scottish Terrier Scottie
# Adding Variable to Test Set:  Breed1_Name_Setter
# Adding Variable to Test Set:  Breed1_Name_Shepherd
# Adding Variable to Test Set:  Breed1_Name_Silver
# Adding Variable to Test Set:  Breed1_Name_Spaniel
# Adding Variable to Test Set:  Breed1_Name_Sphynx (hairless cat)
# Adding Variable to Test Set:  Breed1_Name_Swedish Vallhund
# Adding Variable to Test Set:  Breed1_Name_Torbie
# Adding Variable to Test Set:  Breed1_Name_Toy Fox Terrier
# Adding Variable to Test Set:  Breed1_Name_Turkish Van
# Adding Variable to Test Set:  Breed1_Name_Weimaraner
# Adding Variable to Test Set:  Breed1_Name_Welsh Corgi
# Adding Variable to Test Set:  Breed1_Name_Wheaten Terrier
# Adding Variable to Test Set:  Breed1_Name_White German Shepherd
# Adding Variable to Test Set:  Breed1_Name_Wirehaired Terrier
# Adding Variable to Test Set:  Breed1_Name_Yellow Labrador Retriever
# Adding Variable to Test Set:  Breed1_Name_Yorkshire Terrier Yorkie
# Adding Variable to Test Set:  Breed2_Name_Affenpinscher
# Adding Variable to Test Set:  Breed2_Name_Afghan Hound
# Adding Variable to Test Set:  Breed2_Name_Akbash
# Adding Variable to Test Set:  Breed2_Name_Akita
# Adding Variable to Test Set:  Breed2_Name_American Staffordshire Terrier
# Adding Variable to Test Set:  Breed2_Name_Applehead Siamese
# Adding Variable to Test Set:  Breed2_Name_Australian Shepherd
# Adding Variable to Test Set:  Breed2_Name_Basset Hound
# Adding Variable to Test Set:  Breed2_Name_Bearded Collie
# Adding Variable to Test Set:  Breed2_Name_Belgian Shepherd Dog Sheepdog
# Adding Variable to Test Set:  Breed2_Name_Belgian Shepherd Laekenois
# Adding Variable to Test Set:  Breed2_Name_Birman
# Adding Variable to Test Set:  Breed2_Name_Bluetick Coonhound
# Adding Variable to Test Set:  Breed2_Name_Bobtail
# Adding Variable to Test Set:  Breed2_Name_Border Terrier
# Adding Variable to Test Set:  Breed2_Name_Chartreux
# Adding Variable to Test Set:  Breed2_Name_Chihuahua
# Adding Variable to Test Set:  Breed2_Name_Corgi
# Adding Variable to Test Set:  Breed2_Name_Cymric
# Adding Variable to Test Set:  Breed2_Name_Dilute Calico
# Adding Variable to Test Set:  Breed2_Name_Egyptian Mau
# Adding Variable to Test Set:  Breed2_Name_English Cocker Spaniel
# Adding Variable to Test Set:  Breed2_Name_Exotic Shorthair
# Adding Variable to Test Set:  Breed2_Name_Finnish Spitz
# Adding Variable to Test Set:  Breed2_Name_Fox Terrier
# Adding Variable to Test Set:  Breed2_Name_German Shorthaired Pointer
# Adding Variable to Test Set:  Breed2_Name_Harrier
# Adding Variable to Test Set:  Breed2_Name_Havana
# Adding Variable to Test Set:  Breed2_Name_Hound
# Adding Variable to Test Set:  Breed2_Name_Irish Setter
# Adding Variable to Test Set:  Breed2_Name_Japanese Bobtail
# Adding Variable to Test Set:  Breed2_Name_Japanese Chin
# Adding Variable to Test Set:  Breed2_Name_Korat
# Adding Variable to Test Set:  Breed2_Name_Lowchen
# Adding Variable to Test Set:  Breed2_Name_Manx
# Adding Variable to Test Set:  Breed2_Name_Mastiff
# Adding Variable to Test Set:  Breed2_Name_Munsterlander
# Adding Variable to Test Set:  Breed2_Name_Nebelung
# Adding Variable to Test Set:  Breed2_Name_Norfolk Terrier
# Adding Variable to Test Set:  Breed2_Name_Oriental Long Hair
# Adding Variable to Test Set:  Breed2_Name_Papillon
# Adding Variable to Test Set:  Breed2_Name_Pekingese
# Adding Variable to Test Set:  Breed2_Name_Pointer
# Adding Variable to Test Set:  Breed2_Name_Rhodesian Ridgeback
# Adding Variable to Test Set:  Breed2_Name_Russian Blue
# Adding Variable to Test Set:  Breed2_Name_Saint Bernard
# Adding Variable to Test Set:  Breed2_Name_Samoyed
# Adding Variable to Test Set:  Breed2_Name_Scottish Fold
# Adding Variable to Test Set:  Breed2_Name_Selkirk Rex
# Adding Variable to Test Set:  Breed2_Name_Sheep Dog
# Adding Variable to Test Set:  Breed2_Name_Shetland Sheepdog Sheltie
# Adding Variable to Test Set:  Breed2_Name_Shiba Inu
# Adding Variable to Test Set:  Breed2_Name_Siberian
# Adding Variable to Test Set:  Breed2_Name_Siberian Husky
# Adding Variable to Test Set:  Breed2_Name_Smooth Fox Terrier
# Adding Variable to Test Set:  Breed2_Name_Tonkinese
# Adding Variable to Test Set:  Breed2_Name_Torbie
# Adding Variable to Test Set:  Breed2_Name_Weimaraner
# Adding Variable to Test Set:  Breed2_Name_Welsh Corgi
# Adding Variable to Test Set:  Breed2_Name_Wirehaired Terrier
# Adding Variable to Test Set:  Breed2_Name_Yellow Labrador Retriever
# Adding Variable to Test Set:  Breed2_Name_Yorkshire Terrier Yorkie
# Adding Variable to Test Set:  Gender_Name_Mixed
# Adding Variable to Test Set:  State_Label_Labuan

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(
    X, Y, test_size = validation_size, random_state = random_seed)

# %% [markdown]
# __Hyper-parameter Tuning__

# %%
### Logistic Regression CLASSIFIER
starttime = time.monotonic()
parameters = {'C':[1,5,10,100,1000]}

LG_grid_search = GridSearchCV(LogisticRegression(solver='lbfgs'), parameters, cv=5)
LG_grid_search.fit(x_train,y_train)

print("\n\nThat took ", (time.monotonic()-starttime)/60, " minutes")
print("\n\nBest Results:\n ",LG_grid_search.best_estimator_)
# Out:
# c:\users\sadeeb\anaconda3\envs\testing\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# That took  0.20754999999990104  minutes
#
#
# Best Results:
#   LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
### RANDOM FOREST CLASSIFIER
starttime = time.monotonic()
parameters = {'n_estimators':[100,200,300,400,500,600,700,800,900,1000], 'max_features': ['sqrt', 'log2'], }

RF_grid_search = GridSearchCV(RandomForestClassifier(random_state = random_seed), parameters, cv=5)
RF_grid_search.fit(x_train,y_train)

print("\n\nThat took ", (time.monotonic()-starttime)/60, " minutes")
print("\n\nBest Results:\n ",RF_grid_search.best_estimator_)
# Out:
# That took  17.300266666666722  minutes
#
#
# Best Results:
#   RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)

# %%
### XGBOOST CLASSIFIER
starttime = time.monotonic()
parameters = {'objective':['binary:logistic'],
              'learning_rate': [0.1], #so called `eta` value
              'reg_lambda ': [0.8],
              'max_depth':[4],
              'n_estimators': [300,400,500,700,1000], #number of trees, change it to 1000 for better results
              'seed': [1234]}

clf = GridSearchCV(xgb.XGBClassifier(), parameters, cv=5)
clf.fit(x_train,y_train)

print("\n\nThat took ", (time.monotonic()-starttime)/60, " minutes")
print("\n\nBest Results:\n ",clf.best_estimator_)
# Out:
# That took  18.871100000000055  minutes
#
#
# Best Results:
#   XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)

# %%
def kfold_cross_validation(X,y, col_names):
    #ten cross-validation employed here

    # specify the k-fold cross-validation design
    N_FOLDS = 10
    
    random_seed = 1234
    
    # set up numpy array for storing results
    cv_results = np.zeros((N_FOLDS, len(col_names)))

    kf = model_selection.KFold(n_splits = N_FOLDS, random_state = random_seed)

    index_for_fold = 0 #fold count initialized

    for train_index, test_index in kf.split(X,y):
        print('\nFold index:', index_for_fold + 1,
             '------------------------------------------')
        X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2)

        print('\nShape of input data for this fold:',
              '\nData Set: (Observations, Variables)')
        print('X_train:', X_train.shape)
        print('X_test:',X_test.shape)
        print('y_train:', y_train.shape)
        print('y_test:',y_test.shape)

        index_for_method = 0 #initialize
        for name, reg_model in zip(col_names, models):
            print('\nRegression model evaluation for:', name)
            print(' Scikit Learn method:', reg_model)
            reg_model.fit(X_train, y_train) #fit on the train set for this fold

            #evaluate on the test set for this fold
            y_test_predict = reg_model.predict(X_test)

            fold_method_result =  accuracy_score(y_test, y_test_predict)

            cv_results[index_for_fold, index_for_method] = fold_method_result
            index_for_method += 1

        
        cv_results_df = pd.DataFrame(cv_results)
        cv_results_df.columns = col_names
        index_for_fold += 1
    return cv_results_df

# %%
best_LR = LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn',
          n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
          tol=0.0001, verbose=0, warm_start=False)
best_RF = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='sqrt', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
            oob_score=False, random_state=1234, verbose=0,
            warm_start=False)
best_XGB = xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
       n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
       silent=True, subsample=0.8)

# %%
col_names = ['LR','RF','XGB']
models = [best_LR,
          best_RF,
          best_XGB
         ]

# %%
ten_fold_cv_models = kfold_cross_validation(X, Y, col_names)
# Out:
# Fold index: 1 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
#
# Fold index: 2 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
#
# Fold index: 3 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
# c:\users\sadeeb\anaconda3\envs\testing\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
#
# Fold index: 4 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
#
# Fold index: 5 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
#
# Fold index: 6 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
#
# Fold index: 7 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
#
# Fold index: 8 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
# Fold index: 9 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)
#
# Fold index: 10 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (11994, 394)
# X_test: (2999, 394)
# y_train: (11994,)
# y_test: (2999,)
#
# Regression model evaluation for: LR
#  Scikit Learn method: LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
#
# Regression model evaluation for: RF
#  Scikit Learn method: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=None,
#             oob_score=False, random_state=1234, verbose=0,
#             warm_start=False)
#
# Regression model evaluation for: XGB
#  Scikit Learn method: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=700,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1234,
#        silent=True, subsample=0.8)

# %%
ten_fold_cv_models
# Out:
#          LR        RF       XGB
# 0  0.540847  0.656219  0.639213
# 1  0.549517  0.657219  0.659220
# 2  0.540514  0.653218  0.643548
# 3  0.545515  0.647549  0.646549
# 4  0.537846  0.648883  0.638546
# 5  0.544181  0.665555  0.642548
# 6  0.539180  0.659553  0.652551
# 7  0.540514  0.667889  0.647883
# 8  0.547516  0.673891  0.654552
# 9  0.540847  0.670223  0.651884

# %%
ten_fold_cv_models.std()
# Out:
# LR     0.003832
# RF     0.009052
# XGB    0.006845
# dtype: float64

# %%
ten_fold_cv_models.mean()
# Out:
# LR     0.542648
# RF     0.660020
# XGB    0.647649
# dtype: float64

# %% [markdown]
# __Test best models on a single train-test split__

# %%
#Logistic Regression
best_LR.fit(x_train, y_train)
predictions_LR = best_LR.predict(x_test)
#how accuracy is it?
#print("Quadratic Weighted Kappa Score \n", quadratic_weighted_kappa(y_test, predictions_LR))
print("Accuracy Score \n", accuracy_score(y_test, predictions_LR))
print("Confusion Matrix", "\n",  confusion_matrix(y_test, predictions_LR))
print("Classification Report", "\n", classification_report(y_test, predictions_LR))
# Out:
# Accuracy Score
#  0.5498499499833278
# Confusion Matrix
#  [[ 645  875]
#  [ 475 1004]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.58      0.42      0.49      1520
#            1       0.53      0.68      0.60      1479
#
#    micro avg       0.55      0.55      0.55      2999
#    macro avg       0.56      0.55      0.54      2999
# weighted avg       0.56      0.55      0.54      2999

# %%
#Random Forest
best_RF.fit(x_train, y_train)
y_pred_RF = best_RF.predict(x_test)

#how accuracy is it?
print("Accuracy Score \n", accuracy_score(y_test, y_pred_RF))
print("Confusion Matrix", "\n",  confusion_matrix(y_test, y_pred_RF))
print("Classification Report", "\n", classification_report(y_test, y_pred_RF))
# Out:
# Accuracy Score
#  0.6768922974324775
# Confusion Matrix
#  [[1007  513]
#  [ 456 1023]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.69      0.66      0.68      1520
#            1       0.67      0.69      0.68      1479
#
#    micro avg       0.68      0.68      0.68      2999
#    macro avg       0.68      0.68      0.68      2999
# weighted avg       0.68      0.68      0.68      2999

# %%
RF_feature_importance_df = pd.DataFrame({"column_names":x_train.columns, "feature_importance": best_RF.feature_importances_})
RF_feature_importance_df = RF_feature_importance_df.sort_values('feature_importance',ascending=False)
f, ax = plt.subplots(figsize=(20, 50))
sns.barplot(x="feature_importance", y="column_names", data=RF_feature_importance_df)
plt.title('Feature importance')
# Out:
# Text(0.5, 1.0, 'Feature importance')

# %%
RF_feature_importance_df_filtered = (RF_feature_importance_df.sort_values('feature_importance',ascending=False)
                                     [RF_feature_importance_df['feature_importance']>=0.01])
f, ax = plt.subplots(figsize=(20, 12))
sns.barplot(x="feature_importance", y="column_names", data=RF_feature_importance_df_filtered)
plt.title('Top 25 Feature importance')
# Out:
# c:\users\sadeeb\anaconda3\envs\testing\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Text(0.5, 1.0, 'Top 25 Feature importance')

# %%
#XGBoost
best_XGB.fit(x_train, y_train)
y_pred_XGB = best_XGB.predict(x_test)

#how accuracy is it?
print("Accuracy Score \n", accuracy_score(y_test, y_pred_XGB))
print("Confusion Matrix", "\n",  confusion_matrix(y_test, y_pred_XGB))
print("Classification Report", "\n", classification_report(y_test, y_pred_XGB))
# Out:
# Accuracy Score
#  0.6668889629876625
# Confusion Matrix
#  [[ 972  548]
#  [ 451 1028]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.68      0.64      0.66      1520
#            1       0.65      0.70      0.67      1479
#
#    micro avg       0.67      0.67      0.67      2999
#    macro avg       0.67      0.67      0.67      2999
# weighted avg       0.67      0.67      0.67      2999

# %%
f, ax = plt.subplots(figsize=(20, 50))
xgb.plot_importance(bst, ax=ax)

# %%
f, ax = plt.subplots(figsize=(20, 12))
xgb.plot_importance(bst, ax=ax, max_num_features= 25)
plt.title('Top 25 Feature importance')
# Out:
# Text(0.5, 1.0, 'Top 25 Feature importance')

# %% [markdown]
# __Predicting Results for Test Set__

# %%
pet_test['PredictedFastAdoption'] = best_RF.predict(final_test_X)

# %%
pet_test['PredictedFastAdoption'].value_counts()
# Out:
# 1    1979
# 0    1969
# Name: PredictedFastAdoption, dtype: int64

# %%
pet_test.to_csv('data/predictions_test.csv', index=False)
